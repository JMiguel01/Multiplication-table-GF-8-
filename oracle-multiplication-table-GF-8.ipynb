# %%
from qiskit import QuantumCircuit
from qiskit import Aer, transpile
from qiskit.tools.visualization import plot_histogram

qc = QuantumCircuit(73,73)
qc.ccx(7,9,12)
qc.ccx(6,10,13)
qc.cx(12,13)
qc.cx(13,14)
qc.ccx(0,5,15)
qc.ccx(2,3,16)
qc.cx(15,16)
qc.cx(16,17)
qc.ccx(14,17,18) #(a10&a8 ^ a11&a7)&(a1&a6 ^ a3&a4)
qc.cx(16,17)
qc.cx(15,16)
qc.ccx(2,3,16)
qc.ccx(0,5,15)
qc.cx(13,14)
qc.cx(12,13)
qc.ccx(6,10,13)
qc.ccx(7,9,12)
######################
qc.ccx(0,10,12)
qc.ccx(0,11,13)
qc.cx(12,13)
qc.cx(13,15) # a1&a11 ^ a1&a12 
qc.ccx(0,4,16)
qc.cx(15,16)
qc.cx(16,19)
qc.ccx(0,5,20)
qc.cx(19,20)
qc.cx(20,21)
qc.ccx(1,9,22)
qc.cx(21,22)
qc.cx(22,23)
qc.ccx(2,9,24)
qc.cx(23,24)
qc.cx(24,25)
qc.ccx(7,11,26)
qc.cx(25,26)
qc.cx(26,27)
qc.ccx(8,9,28)
qc.cx(27,28)
qc.cx(28,29)
qc.ccx(6,10,30)
qc.cx(29,30)
qc.cx(30,31)
qc.ccx(6,11,32)
qc.cx(31,32)
qc.cx(32,23)
qc.ccx(1,3,34)
qc.cx(33,34)
qc.cx(34,35)
qc.ccx(2,3,36)
qc.cx(35,36)
qc.cx(36,37)
qc.ccx(3,7,38)
qc.cx(37,38)
qc.cx(38,39)
qc.ccx(3,8,40)
qc.cx(39,40)
qc.cx(40,41)
qc.ccx(4,6,42)
qc.cx(41,42)
qc.cx(42,43)
qc.ccx(5,6,44)
qc.cx(43,44)
qc.cx(44,45) # (a1&a11 ^ a1&a12)^(a1&a5 ^ a1&a6)^(a10&a2 ^ a10&a3)^(a10&a8 ^ a10&a9)^(a11&a7 ^ a12&a7)^(a2&a4 ^ a3&a4)^(a4&a8 ^ a4&a9)^( a5&a7 ^ a6&a7)
qc.ccx(18,45,46) # #(a10&a8 ^ a11&a7)&(a1&a6 ^ a3&a4) & ((a1&a11 ^ a1&a12)^(a1&a5 ^ a1&a6)^(a10&a2 ^ a10&a3)^(a10&a8 ^ a10&a9)^(a11&a7 ^ a12&a7)^(a2&a4 ^ a3&a4)^(a4&a8 ^ a4&a9)^( a5&a7 ^ a6&a7))
qc.cx(44,45)
qc.cx(43,44)
qc.ccx(5,6,44)
qc.cx(42,43)
qc.cx(41,42)
qc.ccx(4,6,42)
qc.cx(40,41)
qc.cx(39,40)
qc.ccx(3,8,40)
qc.cx(38,39)
qc.cx(37,38)
qc.ccx(3,7,38)
qc.cx(36,37)
qc.cx(35,36)
qc.ccx(2,3,36)
qc.cx(34,35)
qc.cx(33,34)
qc.ccx(1,3,34)
qc.cx(32,23)
qc.cx(31,32)
qc.ccx(6,11,32)
qc.cx(30,31)
qc.cx(29,30)
qc.ccx(6,10,30)
qc.cx(28,29)
qc.cx(27,28)
qc.ccx(8,9,28)
qc.cx(26,27)
qc.cx(25,26)
qc.ccx(7,11,26)
qc.cx(24,25)
qc.cx(23,24)
qc.ccx(2,9,24)
qc.cx(22,23)
qc.cx(21,22)
qc.ccx(1,9,22)
qc.cx(20,21)
qc.cx(19,20)
qc.ccx(0,5,20)
qc.cx(16,19)
qc.cx(15,16)
qc.ccx(0,4,16)
qc.cx(13,15) # a1&a11 ^ a1&a12 
qc.cx(12,13)
qc.ccx(0,11,13)
qc.ccx(0,10,12)
###############
qc.ccx(14,17,18) #uncomputation
qc.x(9)
qc.cx(9,12) # ~a10
qc.x(9)
qc.cx(11,12) 
qc.cx(12,13) # (~a10 ^ a12)
qc.cx(7,13) 
qc.cx(13,14) # (~a10 ^ a12 ^ a8)
############
qc.ccx(7,9,15) # (a10&a8) 
qc.cx(14,15)
qc.cx(15,17) # (~a10 ^ a12 ^ a8 ^ a10&a8)
qc.ccx(6,10,19) # a11&a7
qc.cx(17,19)
qc.cx(19,21)
qc.ccx(8,10,22)
qc.cx(21,22)
qc.cx(22,23)
qc.ccx(7,11,24)
qc.cx(23,24)
qc.cx(24,25)  #(~a10 ^ a12 ^ a8 ^ a10&a8 ^ a11&a7 ^ a11&a9 ^ a12&a8)
qc.cx(23,24)
qc.ccx(7,11,24)
qc.cx(22,23)
qc.cx(21,22)
qc.ccx(8,10,22)
qc.cx(19,21)
qc.cx(17,19)
qc.ccx(6,10,19) 
qc.cx(15,17)
qc.cx(14,15)
qc.ccx(7,9,15)
qc.cx(13,14) # (~a10 ^ a12 ^ a8)
qc.cx(7,13)
qc.cx(12,13) # descomputation (~a10 ^ a12)
qc.cx(11,12) 
qc.x(9)
qc.cx(9,12) # ~a10
qc.x(9)
qc.ccx(25,46,47)
qc.ccx(18,45,46) ## uncomputation
#############

qc.x(0)
qc.cx(0,12)
qc.x(0)
qc.cx(1,12)
qc.cx(12,13) # (~a1 ^ a2)
qc.cx(5,13)
qc.cx(13,14) #(~a1 ^ a2 ^ a6)
qc.ccx(0,5,12)
qc.cx(14,15)
qc.cx(15,16) #(~a1 ^ a2 ^ a6 ^ a1&a6)
qc.ccx(1,5,17)
qc.cx(16,17)
qc.cx(17,19)
qc.ccx(2,3,20)
qc.cx(18,20)
qc.cx(20,21)
qc.ccx(2,4,22)
qc.cx(21,22)
qc.cx(22,23)
qc.ccx(23,47,48) # (a10&a8 ^ a11&a7)&(a1&a6 ^ a3&a4)&(a1&a11 ^ a1&a12 ^ a1&a5 ^ a1&a6 ^ a10&a2 ^ a10&a3 ^ a10&a8 ^ a10&a9 ^ a11&a7 ^ a12&a7 ^ a2&a4 ^ a3&a4 ^ a4&a8 ^ a4&a9 ^ a5&a7 ^ a6&a7)&(~a10 ^ a12 ^ a8 ^ a10&a8 ^ a11&a7 ^ a11&a9 ^ a12&a8)&(~a1 ^ a2 ^ a6 ^ a1&a6 ^ a2&a6 ^ a3&a4 ^ a3&a5)
qc.cx(22,23)
qc.cx(21,22)
qc.ccx(2,4,22)
qc.cx(20,21)
qc.cx(18,20)
qc.ccx(2,3,20)
qc.cx(17,19)
qc.cx(16,17)
qc.ccx(1,5,17)
qc.cx(15,16) #(~a1 ^ a2 ^ a6 ^ a1&a6)
qc.cx(14,15)
qc.ccx(0,5,12)
qc.cx(13,14) #(~a1 ^ a2 ^ a6)
qc.cx(5,13)
qc.cx(12,13) # (~a1 ^ a2)
qc.cx(1,12)
qc.x(0)
qc.cx(0,12)
qc.x(0)
#########
qc.ccx(18,45,46) # uncomputation
qc.x(0)
qc.cx(0,12)
qc.x(0)
qc.cx(9,12)
qc.cx(12,13)
qc.cx(11,13)
qc.cx(13,14)
qc.cx(1,14)
qc.cx(14,15)
qc.cx(3,15)
qc.cx(15,16)
qc.cx(5,16)
qc.cx(16,17)
qc.cx(6,17)
qc.cx(17,18)
qc.cx(7,18)
qc.cx(18,19)
qc.ccx(0,10,20)
qc.cx(19,20)
qc.cx(20,21)
#############
qc.ccx(0,11,22)
qc.cx(21, 22)
qc.cx(22, 24)
qc.ccx(0,4,25)
qc.cx(24, 25)
qc.cx(25, 26)
############
qc.ccx(0,5,27)
qc.cx(26, 27)
qc.cx(27, 28)
qc.ccx(1,9,29)
qc.cx(28, 29)
qc.cx(29, 30)
###########
qc.ccx(2,9,31)
qc.cx(30, 31)
qc.cx(31, 32)
qc.ccx(7,9,33)
qc.cx(32, 33)
qc.cx(33, 34)
############
qc.ccx(8,9,35)
qc.cx(34, 35)
qc.cx(35, 36)
qc.ccx(2,10,37)
qc.cx(36, 37)
qc.cx(37, 38)
###########
qc.ccx(6,10,39)
qc.cx(38, 39)
qc.cx(39, 40)
qc.ccx(8,10,41)
qc.cx(40, 41)
qc.cx(41, 42)
##########
qc.ccx(1,11,43)
qc.cx(42, 43)
qc.cx(43, 44)
qc.ccx(6,11,45)
qc.cx(44, 45)
qc.cx(45, 49)
###########
###########
qc.ccx(7,11,50)
qc.cx(49, 50)
qc.cx(50, 51)
############
########### -------------------------
qc.ccx(1,3,52)
qc.cx(51, 52)
qc.cx(52, 53)
qc.ccx(1,5,53)
qc.cx(53, 54)
###########
qc.cx(54, 55)
qc.ccx(2,3,56)
qc.cx(55, 56)
qc.cx(56, 57)
qc.ccx(2,4,58)
qc.cx(57, 58)
qc.cx(58, 59)
qc.ccx(3,7,60)
qc.cx(59, 60)
qc.cx(60, 61)
###########
qc.ccx(3,8,62)
qc.cx(61, 62)
qc.cx(62, 63)
qc.ccx(4,6,64)
qc.cx(63, 64)
qc.cx(64, 65)
###########
qc.ccx(4,8,66)
qc.cx(65, 66)
qc.cx(66, 67)
qc.ccx(5,6,68)
qc.cx(67, 68)
qc.cx(68, 69)
#############
qc.ccx(5,7,70)
qc.cx(69, 70)
qc.cx(70, 71)
###########
qc.ccx(47,71,72) # Answer
###########uncomputation
qc.cx(70, 71)
qc.cx(69,70)
qc.ccx(5,7,70)
qc.cx(68, 69)
qc.cx(67, 68)
qc.ccx(5,6,68)
qc.cx(66, 67)
qc.cx(65, 66)
qc.ccx(4,8,66)
qc.cx(64, 65)
qc.cx(63, 64)
qc.ccx(4,6,64)
qc.cx(62, 63)
qc.cx(61, 62)
qc.ccx(3,8,62)
qc.cx(60, 61)
qc.cx(59, 60)
qc.ccx(3,7,60)
qc.cx(58, 59)
qc.cx(57, 58)
qc.ccx(2,4,58)
qc.cx(56, 57)
qc.cx(55, 56)
qc.ccx(2,3,56)
qc.cx(54, 55)
qc.cx(53, 54)
qc.ccx(1,5,53)
qc.cx(52, 53)
qc.cx(51, 52)
qc.ccx(1,3,52)
qc.cx(50, 51)
qc.cx(49, 50)
qc.ccx(7,11,50)
qc.cx(48, 49)
qc.cx(44, 45)
qc.ccx(6,11,45)
qc.cx(43, 44)
qc.cx(42, 43)
qc.ccx(1,11,43)
qc.cx(41, 42)
qc.cx(40, 41)
qc.ccx(8,10,41)
qc.cx(39, 40)
qc.cx(38, 39)
qc.ccx(6,10,39)
qc.cx(37, 38)
qc.cx(36, 37)
qc.ccx(2,10,37)
qc.cx(35, 36)
qc.cx(34, 35)
qc.ccx(8,9,35)
qc.cx(33, 34)
qc.cx(32, 33)
qc.ccx(7,9,33)
qc.cx(31, 32)
qc.cx(30, 31)
qc.ccx(2,9,31)
qc.cx(29, 30)
qc.cx(28, 29)
qc.ccx(1,9,29)
qc.cx(27, 28)
qc.cx(26, 27)
qc.ccx(0,5,27)
qc.cx(25, 26)
qc.cx(24, 25)
qc.ccx(0,4,25)
qc.cx(22, 24)
qc.cx(21, 22)
qc.ccx(0,11,22)
qc.cx(20, 21)
qc.cx(19, 20)
qc.ccx(0,10,20)
qc.cx(18, 19)
qc.cx(7,18)
qc.cx(17, 18)
qc.cx(6,17)
qc.cx(16, 17)
qc.cx(5,16)
qc.cx(15, 16)
qc.cx(3,15)
qc.cx(14, 15)
qc.cx(1,14)
qc.cx(13, 14)
qc.cx(11,13)
qc.cx(12,13)
qc.cx(9,12)
qc.x(0)
qc.cx(0,12)
qc.x(0)
qc.ccx(23,47,48) #uncomputation

#qc.measure(range(73),range(73))
qc.draw()
# Out:
#                                                                             »
#  q_0: ────────────■───────────────────────────────────────■──────────────■──»
#                   │                                       │              │  »
#  q_1: ────────────┼───────────────────────────────────────┼──────────────┼──»
#                   │                                       │              │  »
#  q_2: ────────────┼────■─────────────────────────────■────┼──────────────┼──»
#                   │    │                             │    │              │  »
#  q_3: ────────────┼────■─────────────────────────────■────┼──────────────┼──»
#                   │    │                             │    │              │  »
#  q_4: ────────────┼────┼─────────────────────────────┼────┼──────────────┼──»
#                   │    │                             │    │              │  »
#  q_5: ────────────■────┼─────────────────────────────┼────■──────────────┼──»
# ...
